# %% [markdown]
# # Define the networks
# A list for the system to sequentially move through and train mulitple networks.

# %%
import torch
'''
For each network create a array of x variables:
    0. Name of the network test (No spaces allowed)
    1. Type of network -> this will be used to call the network from the script
    2. Path to the network. <- this will need to be added by the trainer once it has done training
    3. If it is a binary Network (Bool)
    4. The BNN accuracy (None <- if a BNN or no accuracy listed)
    5. Dataset that the system works off, Will select the python file holding the network
    6. synthesis the network (boolean)
    7. Train the network
    8. Timelimit for the network. If left as None will not set one. Set in Minutes
    9. Input Vector
    10. Conv. layers present
    11. number of bits
    12. Previous network to load
'''

networkList = []

# networkList.append(["Binary_Network_MNIST_no_HardTann_64_width",
#                     "Courbariaux_Binary_Net_MNIST",
#                     None,
#                     True,
#                     "",
#                     "MNIST",
#                     False,
#                     True,
#                     10*60,
#                     '(1,1,28,28)',
#                     False,
#                     None,
#                     None
#                    ])

# networkList.append(["Trinary-MNIST",
#                     "QuantTrinaryFCMNIST",
#                     None,
#                     False,
#                     100,
#                     "MNIST",
#                     False,
#                     True,
#                     10*60,
#                     '(1,1,28,28)',
#                     False,
#                     None,
#                     None])

# networkList.append(["FINNv2_binary_sqrHingeLoss_LearnRateDecay",
#                     "FINNv2",
#                     None,
#                     True, # network is binary
#                     100,
#                     "CIFAR10",
#                     False, # Synth Network
#                     True, # Train network
#                     5*60, # minutes to train
#                     '(1,3,32,32)', # Input vector
#                     True,# Conv layers present
#                     1,
#                    None]) 
# networkList.append(["FINNv2_trinary_NonBinary_5hours",
#                     "FINNv2",
#                     None,
#                     False, # Use the other form of training
#                     100,
#                     "CIFAR10",
#                     False, # Synth Network
#                     True, # Train network
#                     5*60, # minutes to train
#                     '(1,3,32,32)', # Input vector
#                     True,# Conv layers present
#                    2]) 
# networkList.append(["TrinaryLenetv4_5Hours",
#                     "Lenet5v4",
#                     None,
#                     False, # Use the other form of training
#                     100,
#                     "CIFAR10",
#                     False, # Synth Network
#                     True, # Train network
#                     5*60, # minutes to train
#                     '(1,3,32,32)', # Input vector
#                     True,# Conv layers present
#                    2]) 
# networkList.append(["Lenet5v4_1bit",
#                     "Lenet5v4",
#                     None,
#                     True,
#                     100,
#                     "CIFAR10",
#                     False, # Synth Network
#                     True, # Train network
#                     5*60, # minutes to train
#                     '(1,3,32,32)', # Input vector
#                     True,
#                    1,
#                    None]) # Conv layers present
# networkList.append(["BNN_Conv",
#                     "BNN_Conv",
#                     None,
#                     True,
#                     100,
#                     "CIFAR10",
#                     False, # Synth Network
#                     True, # Train network
#                     5*60, # minutes to train
#                     '(1,3,32,32)', # Input vector
#                     True,
#                    None,
#                    None]) # Conv layers present


# networkList.append(["Lenet5v4_7bit",
#                     "Lenet5v4",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False, # Synth Network
#                     True, # Train network
#                     10*60, # minutes to train
#                     '(1,3,32,32)', # Input vector
#                     True,
#                    7,
#                    None]) # Conv layers present

# networkList.append(["8-bit-MNIST",
#                     "Quant8BitFCMNIST",
#                     84,
#                     False,
#                     100,
#                     "MNIST",
#                     False,
#                     True,
#                     60*10,
#                     '(1,1,28,28)',
#                     False,
#                     None,
#                     None
#                    ])
# networkList.append(["Trinary-MNIST-32Hidden",
#                     "QuantTrinaryFCMNIST32",
#                     None,
#                     False,
#                     100,
#                     "MNIST",
#                     False,
#                     True,
#                     10*60,
#                     '(1,1,28,28)',
#                     False,
#                     None,
#                     None])
# networkList.append(["Trinary-MNIST-300Hidden",
#                     "QuantTrinaryFCMNIST300",
#                     None,
#                     False,
#                     100,
#                     "MNIST",
#                     False,
#                     True,
#                     10*60,
#                     '(1,1,28,28)',
#                     False,
#                     None,
#                     None])

# networkList.append(["Calik 8 bit",
#                     "Calik",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     8,
#                     None])
# networkList.append(["Lenet 8-bit",
#                     "Lenet5v4",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     6,
#                     None])
# networkList.append(["Lenet 8-bit",
#                     "Lenet5v4",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     2,
#                     None])
# networkList.append(["Calik 2 bit",
#                     "Calik",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     2,
#                     None])
# networkList.append(["Lenet 8-bit with Bias",
#                     "Lenet5v4withBias",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     6,
#                     None])
# networkList.append(["Lenet5v7withBiashelp",
#                     "Lenet5v7withBias",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     6,
#                     None])
# networkList.append(["MNIST on CIFAR",
#                     "Quant8BitFCMNISTOld",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     None,
#                     None])


# networkList.append(["MNISTv2-2bit",
#                     "Quant8BitFCMNISTv2",
#                     None,
#                     False,
#                     100,
#                     "MNIST",
#                     False,
#                     True,
#                     10*60,
#                     '(1,1,28,28)',
#                     False,
#                     None,
#                     None])

# networkList.append(["Lenetv9 8-bit",
#                     "Lenet5v9",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     None,
#                     None])

# networkList.append(["MNISTv2-2bit",
#                     "QuantTrinaryFCMNIST",
#                     None,
#                     False,
#                     100,
#                     "MNIST",
#                     False,
#                     True,
#                     10*60,
#                     '(1,1,28,28)',
#                     False,
#                     None,
#                     None])

# networkList.append(["Lenetv8 Trinary",
#                     "Lenet5v8Tri",
#                     None,
#                     False,
#                     100,
#                     "CIFAR10",
#                     False,
#                     True,
#                     10*60,
#                     '(1,3,32,32)',
#                     False,
#                     None,
#                     None])

networkList.append(["FC8bit",
                    "FC8bit",
                    None,
                    False,
                    100,
                    "MNIST",
                    False,
                    True,
                    10*60,
                    '(1,1,28,28)',
                    False,
                    None,
                    None])
# networkList.append(["FC2bit",
#                     "FC2bit",
#                     None,
#                     False,
#                     100,
#                     "MNIST",
#                     False,
#                     True,
#                     10*60,
#                     '(1,1,28,28)',
#                     False,
#                     None,
#                     None])

# %% [markdown]
# # Train the network

# %%
# Initialise the network trainer
from NetworkTrainer import Networktrainer
bnnTrainTime = 10 #in hours - will leave hard coded in.
# Need to be able to load and train network from a list of networks. Not a hard coded list.
for i in networkList:
    # load the network
    Trainer = Networktrainer(bnnTrainTime)
    Trainer.load_dataset(i[5])
    exec(f"from {i[5]} import {i[1]}")
    if i[11] is not None:
        exec(f"Network = {i[1]}({i[11]})")
    else:
        exec(f"Network = {i[1]}()")
    
    #========== Train the network============#    
    if i[4] is not None:
        # allow you to load a target percentage of accuracy
        Trainer.binaryAccuracy = i[4]
    
    trainedNetwork = Trainer.trainNetwork(Network,i[3],i[0],i[7],i[8])
    i[2] = Trainer.path # Recover the path of the saved networks tensors
# Out:
# The Amount of time that the BNN will have to train is: 10 hours
# Training on: cuda:0
# Training Class initalised at: 2023-09-28 23:51:25.971299
# loading dataset: CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified
# Dataset loaded
# The network is not binary
# Max number of epochs for the training is 999 for both BNN and NN.
# [1,  2000] loss: 2.285
# [1,  4000] loss: 2.263
# [1,  6000] loss: 2.217
# [1,  8000] loss: 2.190
# [1, 10000] loss: 2.171
# [1, 12000] loss: 2.159
# Current Accuracy is 20
# [2,  2000] loss: 2.150
# [2,  4000] loss: 2.127
# [2,  6000] loss: 2.156
# [2,  8000] loss: 2.157
# [2, 10000] loss: 2.132
# [2, 12000] loss: 2.115
# Current Accuracy is 21
# [3,  2000] loss: 2.102
# [3,  4000] loss: 2.108
# [3,  6000] loss: 2.120
# [3,  8000] loss: 2.101
# [3, 10000] loss: 2.109
# [3, 12000] loss: 2.095
# Current Accuracy is 22
# [4,  2000] loss: 2.091
# [4,  4000] loss: 2.085
# [4,  6000] loss: 2.152
# [4,  8000] loss: 2.139
# ...
